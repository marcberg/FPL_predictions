# %%
import pandas as pd 
import os

# %%
pd.set_option('display.max_columns', None)

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Marcus Bergdahl\\data_science_projects\\FPL_predictions\\artifacts\\fetched_data'

# %%
games = pd.read_csv(os.getcwd() + '/get_game_list.csv')
player_details = pd.read_csv(os.getcwd() + '/get_player_details.csv')
player_id = pd.read_csv(os.getcwd() + '/get_player_id.csv')
player_info = pd.read_csv(os.getcwd() + '/get_player_info.csv')
player_name = pd.read_csv(os.getcwd() + '/get_player_name.csv')
round_info = pd.read_csv(os.getcwd() + '/get_round_info.csv')

# %%
games.loc[games.finished == False]
# Out:
#      GW   id home  team_h away  team_a  finished               kickoff
# 369  37  319  NEW      14  CRY       6     False  2023-05-25T19:00:00Z  \
# 370  38  371  AVL       1  NaN      20     False  2023-05-28T15:30:00Z
# 371  38  372  BOU       2  CHE       5     False  2023-05-28T15:30:00Z
# 372  38  373  BHA       4  MUN      13     False  2023-05-28T15:30:00Z
# 373  38  374  CRY       6  NFO      15     False  2023-05-28T15:30:00Z
# 374  38  375  EVE       7  SOU      16     False  2023-05-28T15:30:00Z
# 375  38  376  FUL       8  BRE       3     False  2023-05-28T15:30:00Z
# 376  38  377  LIV      11  WHU      18     False  2023-05-28T15:30:00Z
# 377  38  378  LEE      10  WOL      19     False  2023-05-28T15:30:00Z
# 378  38  379  NEW      14  LEI       9     False  2023-05-28T15:30:00Z
# 379  38  380  TOT      17  MCI      12     False  2023-05-28T15:30:00Z
#
#      team_h_score  team_a_score  season_start_year
# 369           NaN           NaN                 22
# ...

# %%
player_details.loc[player_details.element == 3].sort_values('kickoff_time')
# Out:
#        element  fixture  opponent_team  total_points  was_home
# 25801        3       10             13             0     False  \
# 25802        3       11              5             1      True
# 25803        3       24             10             0     False
# 25804        3       31             17             1      True
# 25805        3       49             18             3     False
# ...        ...      ...            ...           ...       ...
# 32           3      329             13             1     False
# 33           3      331              6            13      True
# 34           3      346             15             3     False
# 35           3      351              5             1      True
# 36           3      367             16             2     False
#
#                kickoff_time  team_h_score  team_a_score  round  minutes
# 25801  2019-08-11T13:00:00Z           0.0           1.0      1        0  \
# ...

# %%
player_id.loc[player_id.id == 3]
# Out:
#      playername  id
# 0  Granit Xhaka   3

# %%
player_info.loc[player_info.id == 3]
# Out:
#       chance_of_playing_next_round  chance_of_playing_this_round    code
# 0                            100.0                         100.0   84450  \
# 776                          100.0                         100.0  111457
# 1442                         100.0                          50.0   41270
# 2155                           0.0                           0.0   47431
#
#       cost_change_event  cost_change_event_fall  cost_change_start
# 0                     0                       0                 -2  \
# 776                   0                       0                 -3
# 1442                  0                       0                 -1
# 2155                  0                       0                 -2
#
#       cost_change_start_fall  dreamteam_count  element_type  ep_next  ep_this
# 0                          2                1             3      4.5      4.5  \
# 776                        3                0             2      3.3      3.1
# ...

# %%
round_info.sort_values('deadline_time').loc[round_info['finished'] == False]
# Out:
#     id         name         deadline_time  average_entry_score  finished
# 36  37  Gameweek 37  2023-05-20T10:00:00Z                   42     False  \
# 37  38  Gameweek 38  2023-05-28T14:00:00Z                    0     False
#
#     data_checked  highest_scoring_entry  deadline_time_epoch
# 36         False             10058448.0           1684576800  \
# 37         False                    NaN           1685282400
#
#     deadline_time_game_offset  highest_score  is_previous  is_current
# 36                          0          116.0        False        True  \
# 37                          0            NaN        False       False
#
#     is_next cup_leagues_created h2h_ko_matches_created
# 36    False                True                   True  \
# 37     True               False                  False
#
#                                            chip_plays  most_selected
# 36  [{'chip_name': 'bboost', 'num_played': 292434}...          318.0  \
# ...
